# %%
import pandas as pd
series_test = pd.Series([100, 200, 300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48,
                         2000: 65,
                         2001: 89})
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %%
frame_test = pd.DataFrame({1995: [74, 35 ,45],
                           2001: [23, 12 ,78],
                           2008: [14,65,34]})
frame_test
# Out:
#    1995  2001  2008
# 0    74    23    14
# 1    35    12    65
# 2    45    78    34

# %%
frame_test = pd.DataFrame ([[74, 35 ,45],
                           [23, 12 ,78],
                           [14,65,34]], columns=[1995, 2000, 2005 ])
frame_test
# Out:
#    1995  2000  2005
# 0    74    35    45
# 1    23    12    78
# 2    14    65    34

# %%
#read data

pd.options.display.max_rows = 10
el_universal = pd.read_csv('/home/juan/Documents/web_scrapper/eluniversal_2020_10_08_articles.csv')


type(el_universal)


el_universal
# Out:
#                                                 body  title  \
# 0  \nNos comentan que luego de que Jaime Cárdenas...    NaN
# 1  \nUna especie recientemente descubierta de din...    NaN
# 2  \nSimpatizantes del presidente Andrés Manuel L...    NaN
# 3  \n\nDesde Nuevo León, nos cuentan que cuando t...    NaN
# 4  \nEl Horario de Verano está próximo a terminar...    NaN
# 5  \nA través de redes sociales, el presidente An...    NaN
#
#                                                  url
# 0  https://www.eluniversal.com.mx/nacion/bajo-res...
# 1  https://www.eluniversal.com.mx/ciencia-y-salud...
# 2  https://www.eluniversal.com.mx/nacion/frenaaa-...
# 3  https://www.eluniversal.com.mx/estados/otra-de...
# 4  https://www.eluniversal.com.mx/cartera/telecom...
# 5  https://www.eluniversal.com.mx/nacion/amlo-bea...

# %%
semana = pd.read_csv('/home/juan/Documents/web_scrapper/semana_2020_10_08_articles.csv')
semana
# Out:
#                                                 body  title  \
# 0    ¿Cuáles son las probabilidades de contagio e...    NaN
# 1    ¿Cuáles son las probabilidades de contagio e...    NaN
# 2   La pandemia, un impulso para la digitalizació...    NaN
# 3    ¿Cuáles son las probabilidades de contagio e...    NaN
# 4   Cada vez más locales aparecen con avisos de '...    NaN
# 5    ¿Cuáles son las probabilidades de contagio e...    NaN
# 6    ¿Cuáles son las probabilidades de contagio e...    NaN
# 7    ¿Cuáles son las probabilidades de contagio e...    NaN
# 8    ¿Cuáles son las probabilidades de contagio e...    NaN
#
#                                                  url
# 0  https://www.semana.com/confidenciales/articulo...
# 1  https://www.semana.com/confidenciales/articulo...
# 2  https://www.semana.com/especiales-editoriales/...
# 3  https://www.semana.com/confidenciales/articulo...
# 4  https://www.semana.com/especiales-editoriales/...
# ...

# %%
#index dictionary like:

el_universal[['url','body']]
# Out:
#                                                  url  \
# 0  https://www.eluniversal.com.mx/nacion/bajo-res...
# 1  https://www.eluniversal.com.mx/ciencia-y-salud...
# 2  https://www.eluniversal.com.mx/nacion/frenaaa-...
# 3  https://www.eluniversal.com.mx/estados/otra-de...
# 4  https://www.eluniversal.com.mx/cartera/telecom...
# 5  https://www.eluniversal.com.mx/nacion/amlo-bea...
#
#                                                 body
# 0  \nNos comentan que luego de que Jaime Cárdenas...
# 1  \nUna especie recientemente descubierta de din...
# 2  \nSimpatizantes del presidente Andrés Manuel L...
# 3  \n\nDesde Nuevo León, nos cuentan que cuando t...
# 4  \nEl Horario de Verano está próximo a terminar...
# 5  \nA través de redes sociales, el presidente An...

# %%
#numpy like

el_universal.iloc[1:3]
# Out:
#                                                 body  title  \
# 1  \nUna especie recientemente descubierta de din...    NaN
# 2  \nSimpatizantes del presidente Andrés Manuel L...    NaN
#
#                                                  url
# 1  https://www.eluniversal.com.mx/ciencia-y-salud...
# 2  https://www.eluniversal.com.mx/nacion/frenaaa-...

# %%
el_universal.iloc[3]['url']
# Out:
# 'https://www.eluniversal.com.mx/estados/otra-de-don-samuel-ahora-le-dan-olimpicamente-el-avion'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \nNos comentan que luego de que Jaime Cárdenas...
# 1    \nUna especie recientemente descubierta de din...
# 2    \nSimpatizantes del presidente Andrés Manuel L...
# 3    \n\nDesde Nuevo León, nos cuentan que cuando t...
# 4    \nEl Horario de Verano está próximo a terminar...
# Name: body, dtype: object

# %%
el_universal.loc[:,'body' : 'title'] # : singinifca quiero todas las filas
# Out:
#                                                 body  title
# 0  \nNos comentan que luego de que Jaime Cárdenas...    NaN
# 1  \nUna especie recientemente descubierta de din...    NaN
# 2  \nSimpatizantes del presidente Andrés Manuel L...    NaN
# 3  \n\nDesde Nuevo León, nos cuentan que cuando t...    NaN
# 4  \nEl Horario de Verano está próximo a terminar...    NaN
# 5  \nA través de redes sociales, el presidente An...    NaN

# %%
# data wrangling añadir nespaper_ud al data frame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                 body  title  \
# 0  \nNos comentan que luego de que Jaime Cárdenas...    NaN
# 1  \nUna especie recientemente descubierta de din...    NaN
# 2  \nSimpatizantes del presidente Andrés Manuel L...    NaN
# 3  \n\nDesde Nuevo León, nos cuentan que cuando t...    NaN
# 4  \nEl Horario de Verano está próximo a terminar...    NaN
# 5  \nA través de redes sociales, el presidente An...    NaN
#
#                                                  url newspaper_uid
# 0  https://www.eluniversal.com.mx/nacion/bajo-res...   eluniversal
# 1  https://www.eluniversal.com.mx/ciencia-y-salud...   eluniversal
# 2  https://www.eluniversal.com.mx/nacion/frenaaa-...   eluniversal
# 3  https://www.eluniversal.com.mx/estados/otra-de...   eluniversal
# 4  https://www.eluniversal.com.mx/cartera/telecom...   eluniversal
# 5  https://www.eluniversal.com.mx/nacion/amlo-bea...   eluniversal

# %%
# obtener host

from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                 body  title  \
# 0  \nNos comentan que luego de que Jaime Cárdenas...    NaN
# 1  \nUna especie recientemente descubierta de din...    NaN
# 2  \nSimpatizantes del presidente Andrés Manuel L...    NaN
# 3  \n\nDesde Nuevo León, nos cuentan que cuando t...    NaN
# 4  \nEl Horario de Verano está próximo a terminar...    NaN
# 5  \nA través de redes sociales, el presidente An...    NaN
#
#                                                  url newspaper_uid  \
# 0  https://www.eluniversal.com.mx/nacion/bajo-res...   eluniversal
# 1  https://www.eluniversal.com.mx/ciencia-y-salud...   eluniversal
# 2  https://www.eluniversal.com.mx/nacion/frenaaa-...   eluniversal
# 3  https://www.eluniversal.com.mx/estados/otra-de...   eluniversal
# 4  https://www.eluniversal.com.mx/cartera/telecom...   eluniversal
# 5  https://www.eluniversal.com.mx/nacion/amlo-bea...   eluniversal
#
#                      host
# 0  www.eluniversal.com.mx
# ...

# %%
el_universal['host'].value_counts()  #cuenta los diferentes dominios que aportan a la página el universal
# Out:
# www.eluniversal.com.mx    6
# Name: host, dtype: int64

# %%
#missing data rellenar datos faltantes 

missing_title_mask = el_universal['title'].isna()
missing_titles = (el_universal[missing_title_mask]['url']
    .str.extract(r'(?P<missing_titles>[^/]+)$')
    .applymap(lambda title: title.split('-'))
    .applymap(lambda title_word_list: ' '.join(title_word_list)))

missing_titles
